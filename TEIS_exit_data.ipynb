# %%
import pandas as pd
import re
import numpy as np
import datetime
from datetime import date

# %%
exit_data = pd.read_csv('/Users/k.simmons/Desktop/NSS/data analytics bootcamp/Python/Data/TEIS Exit Data for NSS.csv', nrows=2251)

# %%
exit_data
# Out:
#      POE  Child ID       DOB Notification Date Initial Eligibility Date  \
# 0     UC    471738   2/28/19          10/17/19                 10/29/19
# 1     FT    449030   7/22/18           11/7/18                  12/3/18
# 2     FT    463311    7/9/17           5/24/19                  6/19/19
# 3     FT    463313    7/9/17           5/24/19                  6/19/19
# 4     FT    469194   8/31/17            9/4/19                  10/2/19
# ...   ..       ...       ...               ...                      ...
# 2246  GN    463962    7/2/17            6/6/19                  6/24/19
# 2247  GN    454305    7/6/17           1/24/19                  2/25/19
# 2248  GN    450369   8/16/17          11/28/18                 12/13/18
# 2249  GN    476783  11/24/17           1/22/20                  2/21/20
# 2250  MD    486852   4/10/20           7/28/20                   9/4/20
#
#      Initial IFSP Date Latest IFSP Date  \
# 0             10/31/19          5/12/20
# ...

# %%
exit_data.shape
# Out:
# (2251, 11)

# %%
exit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2251 entries, 0 to 2250
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   POE                       2251 non-null   object
#  1   Child ID                  2251 non-null   int64
#  2   DOB                       2251 non-null   object
#  3   Notification Date         2251 non-null   object
#  4   Initial Eligibility Date  2251 non-null   object
#  5   Initial IFSP Date         2251 non-null   object
#  6   Latest IFSP Date          2210 non-null   object
#  7   Exit Reason               2251 non-null   object
#  8   Exit Date                 2251 non-null   object
#  9   Days from I-IFSP to Exit  2251 non-null   int64
#  10  Exit Note                 2251 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 193.6+ KB

# %%
exit_note = pd.DataFrame(exit_data['Exit Note'])

# %%
exit_note.head()
# Out:
#                                                                                                                                                                                                                                                      Exit Note
# 0                                                                                                                                                                                                                      * No Exit ECO available due to COVID-19
# 1                                                                                  ***family moving out of state March 2021, and will complete the Part B eligibility testing in their new state; SC provided EI program information for Missouri to family***
# ...

# %%
pd.set_option('display.max_colwidth', None)

# %%
exit_note.head()
# Out:
#                                                                                                                                                                                                                                                      Exit Note
# 0                                                                                                                                                                                                                      * No Exit ECO available due to COVID-19
# 1                                                                                  ***family moving out of state March 2021, and will complete the Part B eligibility testing in their new state; SC provided EI program information for Missouri to family***
# ...

# %%
exit_note.head(50)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Exit Note
# ...

# %% [markdown]
# Creating two new columns as placeholders for extracted dates

# %%
exit_note.loc[:,'Exit Date note'] = ''
exit_note.loc[:,'Reopened date'] = ''

# %% [markdown]
# assigning first 'Exit Note' string entry a variable for testing with regex

# %%
exit_note
# Out:
#                                                                                                                                                                                                                                                         Exit Note  \
# 0                                                                                                                                                                                                                         * No Exit ECO available due to COVID-19
# 1                                                                                     ***family moving out of state March 2021, and will complete the Part B eligibility testing in their new state; SC provided EI program information for Missouri to family***
# ...

# %%
x = exit_note.loc[37, 'Exit Note']

# %%
match = re.findall((r'(\d{2}/\d{2}/\d{4})'), x)
if match:
        print(match)
else:
        print('no match')
# Out:
# ['03/10/2020', '03/06/2020']

# %% [markdown]
# following cell is original regex that finds Exit Date: xx/xx/xxxx and then splits and strips necessary items

# %%
#edmatch = re.findall(r'(Exit Date:.*?\d{2}/\d{2}/\d{4})', x)
#if edmatch:
    #edstring = str(edmatch)
    #edsplitspring = edstring.split(': ')
    #date = str(edsplitspring[1])
    #edate = date.strip("']")
    #print(edate)

#else:
        #print('no match')

# %%
exit_note_date = []
for index, row in exit_note.iterrows():
    x = row['Exit Note']
    edmatch = re.findall(r'(Exit Date:.*?\d{2}/\d{2}/\d{4})', x)
    if len(edmatch) > 0:
        edstring = edmatch[0].strip('Exit Date:   ')
        exit_note_date.append(edstring)
    else:
        exit_note_date.append('null')

        print(edstring)

exit_note['Exit Date note'] = pd.Series(exit_note_date)
# Out:
# 07/19/2019
# 07/19/2019
# 07/19/2019
# 07/19/2019
# 07/19/2019
# 11/26/2019
# 11/26/2019
# 04/07/2020
# 04/07/2020
# 04/07/2020
# 06/17/2018
# 06/17/2018
# 06/17/2018
# 12/05/2019
# 12/05/2019
# 12/05/2019
# 12/05/2019
# 12/10/2019
# 12/10/2019
# 09/27/2019
# 09/27/2019
# 09/27/2019
# 09/27/2019
# 01/21/2020
# 01/21/2020
# 01/21/2020
# 01/21/2020
# 01/21/2020
# 01/21/2020
# 03/06/2020
# 03/06/2020
# 03/06/2020
# 03/06/2020
# 03/06/2020
# 03/06/2020
# 07/12/2019
# 07/12/2019
# 07/12/2019
# 07/12/2019
# 07/12/2019
# 07/12/2019
# 07/12/2019
# 07/11/2019
# 07/11/2019
# 10/26/2018
# 10/26/2018
# 10/26/2018
# 08/10/2020
# 08/10/2020
# 09/11/2020
# 09/11/2020
# 09/11/2020
# 09/11/2020
# 09/11/2020
# 09/11/2020
# 09/11/2020
# 09/11/2020
# 09/11/2020
# 09/11/2020
# 09/11/2020
# 09/11/2020
# 09/11/2020
# 08/27/2018
# 08/27/2018
# 11/07/2019
# 05/28/2019
# 10/22/2020
# 10/22/2020
# 10/22/2020
# 10/22/2020
# 10/22/2020
# 10/22/2020
# 10/22/2020
# 10/22/2020
# 10/22/2020
# 12/23/2019
# ...

# %%
reopened_date = []
for index, row in exit_note.iterrows():
    x = row['Exit Note']
    edmatch = re.findall(r'(Reopened:.*?\d{2}/\d{2}/\d{4})', x)
    if len(edmatch) > 0:
        edstring = edmatch[0].strip('Reopened:  ')
        reopened_date.append(edstring)
    else:
        reopened_date.append('null')

        print(edstring)

exit_note['Reopened date'] = pd.Series(reopened_date)
# Out:
# 07/19/2019
# 07/19/2019
# 07/19/2019
# 07/19/2019
# 07/19/2019
# 04/06/2020
# 04/06/2020
# 02/05/2021
# 02/05/2021
# 02/05/2021
# 01/11/2019
# 01/11/2019
# 01/11/2019
# 02/28/2020
# 02/28/2020
# 02/28/2020
# 02/28/2020
# 02/07/2020
# 02/07/2020
# 01/10/2020
# 01/10/2020
# 01/10/2020
# 01/10/2020
# 08/26/2020
# 08/26/2020
# 08/26/2020
# 08/26/2020
# 08/26/2020
# 08/26/2020
# 03/10/2020
# 03/10/2020
# 03/10/2020
# 03/10/2020
# 03/10/2020
# 03/10/2020
# 09/15/2020
# 09/15/2020
# 09/15/2020
# 09/15/2020
# 09/15/2020
# 09/15/2020
# 09/15/2020
# 08/01/2019
# 08/01/2019
# 04/25/2019
# 04/25/2019
# 04/25/2019
# 10/13/2020
# 10/13/2020
# 12/01/2020
# 12/01/2020
# 12/01/2020
# 12/01/2020
# 12/01/2020
# 12/01/2020
# 12/01/2020
# 12/01/2020
# 12/01/2020
# 12/01/2020
# 12/01/2020
# 12/01/2020
# 12/01/2020
# 11/19/2018
# 11/19/2018
# 01/06/2020
# 10/06/2020
# 05/20/2021
# 05/20/2021
# 05/20/2021
# 05/20/2021
# 05/20/2021
# 05/20/2021
# 05/20/2021
# 05/20/2021
# 05/20/2021
# 01/08/2020
# ...

# %%
exit_note.head(50)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Exit Note  \
# ...

# %% [markdown]
# match1 = re.findall(r'(Reopened:.*?\d{2}/\d{2}/\d{4})', x)
# if match1:
#     print(match1)
# else:
#         print('no match')

# %% [markdown]
# no workey vvv

# %% [markdown]
# match = re.search(('/^.*?\bExit\b.*?\bDate\b.*?(\d{2}/\d{2}/\d{4})'), x)
# if match:
#         print(match)
# else:
#         print('no match')

# %% [markdown]
# match = re.search(('Exit'), x)
# if match:
#         print(match)
# else:
#         print('no match')
